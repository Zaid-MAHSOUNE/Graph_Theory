# %%
def DFS(graph,start):
    visited = []
    stack = []

    stack.append(start)
    visited.append(start)

    while stack :
        v = stack.pop()
        if v not in visited :
            visited.append(v)

        for n in graph.neighbors(v):
            if n not in visited :
                stack.append(n)
                
        
    return visited

# %%
h = Graph(9)
h.add_edges([[0,1],[0,6],[1,3],[1,4],[1,2],[6,7],[7,8],[4,5]])
h.show()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
DFS(h,3)
# Out:
# [3, 1, 4, 5, 2, 0, 6, 7, 8]

# %%
list(h.depth_first_search(3))
# Out:
# [3, 1, 4, 5, 2, 0, 6, 7, 8]
